# %% [markdown]
# # PiCRUST2 Functional Analysis

# %%
# Import libraries
import os 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %%
# Set paths and file names
cwd = os.getcwd()
dir = "pipeline-test"
kegg_filename = "KO_pred_metagenome_unstrat_descrip.tsv"
ec_filename = "EC_pred_metagenome_unstrat_descrip.tsv"
metacyc_filename = "METACYC_path_abun_unstrat_descrip.tsv"
meta_filename = "Metadata.tsv"
condition_col = "treatment1"

# %% [markdown]
# ### KEGG Functional Orthologs

# %%
print(cwd)
# Out:
# /Users/camilla.callierotti/ampliseq-visualizations

# %%
# Load Data
meta = pd.read_csv(f"{cwd}/input/{dir}/Metadata.tsv", sep="\t")
kegg = pd.read_csv(f"{cwd}/input/{dir}/picrust/KO_pred_metagenome_unstrat_descrip.tsv", sep="\t", header=0)

# %%
# Process KEGG orthology file to create kegg_categories
def parse_kegg_file(filepath):
    with open(filepath, "r") as file:
        kegg_data = file.readlines()
    
    entries = []
    modules = []
    categories = []
    
    module = None
    category = None
    
    for line in kegg_data:

        # Level A - Category (Starts with "A091")
        if line.startswith("A091"):
            category = line[1:].strip() # remove A 
            module = None # reset module when new category starts

        # Level B - Module
        elif line.startswith("B") and category:
            module = line.strip().split("  ", 1)[-1]

        # Level D - Entries
        elif line.startswith("D") and category and module:
            match = re.search(r"K\d{5,6}", line)
            if match:
                entries.append(match.group())
                modules.append(module)
                categories.append(category)
    
    return pd.DataFrame({"Entry": entries, "Module": modules, "Category": categories})

kegg_categories = parse_kegg_file("input/general/ko00001.keg")
kegg_categories.to_pickle("intermediate/kegg-categories.pkl")

# %%
kegg_categories
# Out:
#         Entry                         Module  \
# 0      K00844  09101 Carbohydrate metabolism
# 1      K12407  09101 Carbohydrate metabolism
# 2      K00845  09101 Carbohydrate metabolism
# 3      K25026  09101 Carbohydrate metabolism
# 4      K01810  09101 Carbohydrate metabolism
# ...       ...                            ...
# 62345  K07220     09194 Poorly characterized
# 62346  K07276     09194 Poorly characterized
# 62347  K07338     09194 Poorly characterized
# 62348  K07586     09194 Poorly characterized
# 62349  K07742     09194 Poorly characterized
#
#                                      Category
# 0                            09100 Metabolism
# 1                            09100 Metabolism
# 2                            09100 Metabolism
# 3                            09100 Metabolism
# 4                            09100 Metabolism
# ...                                       ...
# 62345  09190 Not Included in Pathway or Brite
# 62346  09190 Not Included in Pathway or Brite
# 62347  09190 Not Included in Pathway or Brite
# 62348  09190 Not Included in Pathway or Brite
# 62349  09190 Not Included in Pathway or Brite
#
# [62350 rows x 3 columns]

# %%
# Convert kegg data to long format
value_columns = [col for col in kegg.columns if col not in ["function", "description"]]  # Get all columns that are not function or description
kegg_long = kegg.melt(id_vars=["function"], value_vars=value_columns, var_name="Sample", value_name="Abundance")  # Convert to long format
kegg_long = kegg_long.merge(kegg_categories, left_on="function", right_on="Entry", how="left")  # Add KEGG category to dataframe
kegg_long = kegg_long.merge(meta[["ID", "treatment1"]], left_on="Sample", right_on="ID", how="left").drop(columns=["ID"])  # Add treatment to dataframe
kegg_long["treatment1"] = kegg_long["treatment1"].astype("category")  # Convert treatment to categorical variable

# %%
kegg_long
# Out:
#       function       Sample  Abundance   Entry  \
# 0       K00001   sampleID_1     134.50  K00001
# 1       K00001   sampleID_1     134.50  K00001
# 2       K00001   sampleID_1     134.50  K00001
# 3       K00001   sampleID_1     134.50  K00001
# 4       K00001   sampleID_1     134.50  K00001
# ...        ...          ...        ...     ...
# 26707   K19736  sampleID_2a      12.80  K19736
# 26708   K19744  sampleID_2a      12.80  K19744
# 26709   K19745  sampleID_2a      39.05  K19745
# 26710   K19746  sampleID_2a      25.60  K19746
# 26711   K19784  sampleID_2a      12.80  K19784
#
#                                                   Module  \
# 0                          09101 Carbohydrate metabolism
# 1                          09101 Carbohydrate metabolism
# 2                                 09103 Lipid metabolism
# 3                            09105 Amino acid metabolism
# 4             09108 Metabolism of cofactors and vitamins
# ...                                                  ...
# 26707  09182 Protein families: genetic information pr...
# 26708              09106 Metabolism of other amino acids
# 26709                      09101 Carbohydrate metabolism
# 26710              09106 Metabolism of other amino acids
# 26711                     09191 Unclassified: metabolism
#
#                                      Category treatment1
# 0                            09100 Metabolism          b
# 1                            09100 Metabolism          b
# 2                            09100 Metabolism          b
# 3                            09100 Metabolism          b
# 4                            09100 Metabolism          b
# ...                                       ...        ...
# 26707                 09180 Brite Hierarchies          a
# 26708                        09100 Metabolism          a
# 26709                        09100 Metabolism          a
# 26710                        09100 Metabolism          a
# 26711  09190 Not Included in Pathway or Brite          a
#
# [26712 rows x 7 columns]

# %%
kegg_long[kegg_long["Category"].isna()]
# Out:
#       function       Sample  Abundance Entry Module Category treatment1
# 74      K00050   sampleID_1     411.20   NaN    NaN      NaN          b
# 446     K00356   sampleID_1     307.00   NaN    NaN      NaN          b
# 1489    K01572   sampleID_1       4.00   NaN    NaN      NaN          b
# 2554    K02428   sampleID_1     494.95   NaN    NaN      NaN          b
# 4085    K05962   sampleID_1     248.00   NaN    NaN      NaN          b
# 4355    K06955   sampleID_1     115.20   NaN    NaN      NaN          b
# 4395    K07011   sampleID_1     232.20   NaN    NaN      NaN          b
# 4445    K07088   sampleID_1    1089.45   NaN    NaN      NaN          b
# 4551    K07239   sampleID_1     248.00   NaN    NaN      NaN          b
# 5553    K11189   sampleID_1     468.60   NaN    NaN      NaN          b
# 6752    K00050  sampleID_1a     222.40   NaN    NaN      NaN          a
# 7124    K00356  sampleID_1a      55.00   NaN    NaN      NaN          a
# 8167    K01572  sampleID_1a       0.00   NaN    NaN      NaN          a
# 9232    K02428  sampleID_1a     560.40   NaN    NaN      NaN          a
# 10763   K05962  sampleID_1a      17.00   NaN    NaN      NaN          a
# 11033   K06955  sampleID_1a       2.40   NaN    NaN      NaN          a
# 11073   K07011  sampleID_1a     231.40   NaN    NaN      NaN          a
# 11123   K07088  sampleID_1a     154.40   NaN    NaN      NaN          a
# 11229   K07239  sampleID_1a      17.00   NaN    NaN      NaN          a
# 12231   K11189  sampleID_1a     168.20   NaN    NaN      NaN          a
# 13430   K00050   sampleID_2     635.20   NaN    NaN      NaN          b
# 13802   K00356   sampleID_2     512.00   NaN    NaN      NaN          b
# 14845   K01572   sampleID_2      15.00   NaN    NaN      NaN          b
# 15910   K02428   sampleID_2     764.91   NaN    NaN      NaN          b
# 17441   K05962   sampleID_2     443.00   NaN    NaN      NaN          b
# 17711   K06955   sampleID_2     141.20   NaN    NaN      NaN          b
# 17751   K07011   sampleID_2     284.20   NaN    NaN      NaN          b
# 17801   K07088   sampleID_2    1722.33   NaN    NaN      NaN          b
# 17907   K07239   sampleID_2     443.00   NaN    NaN      NaN          b
# 18909   K11189   sampleID_2     699.93   NaN    NaN      NaN          b
# 20108   K00050  sampleID_2a     274.80   NaN    NaN      NaN          a
# 20480   K00356  sampleID_2a      71.00   NaN    NaN      NaN          a
# 21523   K01572  sampleID_2a       0.00   NaN    NaN      NaN          a
# 22588   K02428  sampleID_2a     636.38   NaN    NaN      NaN          a
# 24119   K05962  sampleID_2a       0.00   NaN    NaN      NaN          a
# 24389   K06955  sampleID_2a      12.80   NaN    NaN      NaN          a
# 24429   K07011  sampleID_2a     296.80   NaN    NaN      NaN          a
# 24479   K07088  sampleID_2a     135.54   NaN    NaN      NaN          a
# 24585   K07239  sampleID_2a       0.00   NaN    NaN      NaN          a
# 25587   K11189  sampleID_2a     211.73   NaN    NaN      NaN          a

# %%
# Category-Group dataframe
kegg_transcoding = kegg_long[["Category", "Module", "Entry"]].drop_duplicates().sort_values(by="Category")

# %%
kegg_transcoding
# Out:
#                                     Category  \
# 0                           09100 Metabolism
# 1603                        09100 Metabolism
# 1602                        09100 Metabolism
# 1600                        09100 Metabolism
# 1599                        09100 Metabolism
# ...                                      ...
# 4592  09190 Not Included in Pathway or Brite
# 4587  09190 Not Included in Pathway or Brite
# 4585  09190 Not Included in Pathway or Brite
# 6677  09190 Not Included in Pathway or Brite
# 74                                       NaN
#
#                                                  Module   Entry
# 0                         09101 Carbohydrate metabolism  K00001
# 1603         09108 Metabolism of cofactors and vitamins  K01652
# 1602                        09105 Amino acid metabolism  K01652
# 1600                      09101 Carbohydrate metabolism  K01652
# 1599                        09105 Amino acid metabolism  K01649
# ...                                                 ...     ...
# 4592  09193 Unclassified: signaling and cellular pro...  K07282
# 4587                         09194 Poorly characterized  K07276
# 4585  09193 Unclassified: signaling and cellular pro...  K07273
# 6677                     09191 Unclassified: metabolism  K19784
# 74                                                  NaN     NaN
#
# [5796 rows x 3 columns]

# %%
y_order = kegg_transcoding["Module"]
y_order
# Out:
# 0                           09101 Carbohydrate metabolism
# 1603           09108 Metabolism of cofactors and vitamins
# 1602                          09105 Amino acid metabolism
# 1600                        09101 Carbohydrate metabolism
# 1599                          09105 Amino acid metabolism
#                               ...
# 4592    09193 Unclassified: signaling and cellular pro...
# 4587                           09194 Poorly characterized
# 4585    09193 Unclassified: signaling and cellular pro...
# 6677                       09191 Unclassified: metabolism
# 74                                                    NaN
# Name: Module, Length: 5796, dtype: object

# %%
# Sort the DataFrame by Category to preserve order
df = kegg_transcoding[["Category", "Module"]].drop_duplicates()
df["Category"] = df["Category"].astype("object").fillna("Unassigned") # treat NAs as a group

# Get unique categories in order
group_labels = df["Category"].unique().tolist()

# Get group bounds based on consecutive counts
group_counts = df["Category"].value_counts(sort=False).loc[group_labels].tolist()
group_bounds = [(i, i + c) for i, c in zip([0] + list(np.cumsum(group_counts)[:-1]), group_counts)]

# Define colors (can repeat or truncate based on number of groups)
group_colors = [
    '#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C',
    '#FB9A99', '#E31A1C', '#6A3D9A', '#FFB3E6',
    '#FFCC99', '#6A3D9A'
][:len(group_labels)]

# Output
print("Group Labels:", group_labels)
print("Group Bounds:", group_bounds)
print("Group Colours:", group_colors)
# Out:
# Group Labels: ['09100 Metabolism', '09120 Genetic Information Processing', '09130 Environmental Information Processing', '09140 Cellular Processes', '09150 Organismal Systems', '09160 Human Diseases', '09180 Brite Hierarchies', '09190 Not Included in Pathway or Brite', 'Unassigned']
# Group Bounds: [(0, 11), (np.int64(11), np.int64(16)), (np.int64(16), np.int64(18)), (np.int64(18), np.int64(22)), (np.int64(22), np.int64(31)), (np.int64(31), np.int64(43)), (np.int64(43), np.int64(46)), (np.int64(46), np.int64(50)), (np.int64(50), np.int64(51))]
# Group Colours: ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C', '#FB9A99', '#E31A1C', '#6A3D9A', '#FFB3E6', '#FFCC99']

# %%
# Create figure
fig, ax = plt.subplots(figsize=(18, 24))

# Remove whitespace in plot
category_positions = range(len(kegg_long['Module'].unique()))
ax.set_ylim(min(category_positions), max(category_positions))

# Plot the boxplot (Horizontal boxplot)
sns.boxplot(x="Abundance",
            y="Module", 
            hue="treatment1", 
            data=kegg_long, 
            order=y_order,
            flierprops=dict(marker='o', markerfacecolor='black', markersize=0.75),
            ax=ax
           )

# Add background colors for each module (shade horizontal regions along y-axis)
for i, (group, (y_start, y_end), color) in enumerate(zip(group_labels, group_bounds, group_colors)):
    ax.axhspan(y_start - 0.5, y_end - 0.5, color=color, alpha=0.3, zorder=0)  # Background color
    ax.text(ax.get_xlim()[1], (y_start + y_end) / 2 - 0.5, group, 
            ha='left', va='center', fontsize=12, fontweight='bold')

# Title and labels
plt.title('KEGG Orthology Relative Abundances by Treatment', fontsize=16, fontweight='bold')
plt.xlabel('Pathway Abundance Value')
plt.ylabel('KEGG Orthology Category')
plt.legend(title='Condition', loc='lower right')

# Save plot
plt.savefig("results/picrust/picrust_kegg.pdf")
plt.show()

# %% [markdown]
# #### To do:
# - Some entries (K###) have NA modules/categories
# - Plot saving cropped
# - Right y label
# - space between right y axis and labels
# - na vales gone

# %% [markdown]
# ### Enzyme Commission Functional Analysis

# %%
# Load Data
meta = pd.read_csv(f"{cwd}/input/{dir}/Metadata.tsv", sep="\t")
ec = pd.read_csv(f"{cwd}/input/{dir}/picrust/{ec_filename}", sep="\t", header=0)

# %%
# Load EC transcoding file
class_mapping = []
subclass_mapping = []

with open("input/general/enzclass.txt", "r") as f:
    for line in f:
        line = line.strip()

        # Match enzyme classes (e.g., "1. -.-  Oxidoreductases.")
        match_class = re.match(r"^(\d+)\.\s+-\.\s+-\.-\s+(.*)", line)

        # Match enzyme subclasses (e.g., "1. 1. -.-  Acting on the CH-OH group of donors.")
        match_subclass = re.match(r"^(\d+)\.\s*(\d+)\.\s+-\.-\s+(.*)", line)

        if match_class:
            class_mapping.append([match_class.group(1), match_class.group(2)])

        if match_subclass:
            subclass_code = f"{match_subclass.group(1)}.{match_subclass.group(2)}"
            subclass_mapping.append([subclass_code, match_subclass.group(3)])

# Convert to DataFrames
class_df = pd.DataFrame(class_mapping, columns=["class", "class_name"])
subclass_df = pd.DataFrame(subclass_mapping, columns=["subclass", "subclass_name"])

# %%
subclass_df
# Out:
#    subclass                                      subclass_name
# 0       1.1               Acting on the CH-OH group of donors.
# 1       1.2     Acting on the aldehyde or oxo group of donors.
# 2       1.3               Acting on the CH-CH group of donors.
# 3       1.4              Acting on the CH-NH2 group of donors.
# 4       1.5               Acting on the CH-NH group of donors.
# ..      ...                                                ...
# 74      7.2  Catalysing the translocation of inorganic cati...
# 75      7.3  Catalysing the translocation of inorganic anio...
# 76      7.4  Catalysing the translocation amino acids and p...
# 77      7.5  Catalysing the translocation carbohydrates and...
# 78      7.6   Catalysing the translocation of other compounds.
#
# [79 rows x 2 columns]

# %%
class_df
# Out:
#   class        class_name
# 0     1  Oxidoreductases.
# 1     2     Transferases.
# 2     3       Hydrolases.
# 3     4           Lyases.
# 4     5       Isomerases.
# 5     6          Ligases.
# 6     7     Translocases.

# %%
ec.dtypes
# Out:
# function        object
# description     object
# sampleID_1     float64
# sampleID_1a    float64
# sampleID_2     float64
# sampleID_2a    float64
# dtype: object

# %%
# Add class and subclass
ec["class"] = ec["function"].str.extract(r"EC:(\d)\.\d")
ec["subclass"] = ec["function"].str.extract(r"EC:(\d\.\d)\..")
ec
# Out:
#           function                                 description  sampleID_1  \
# 0       EC:1.1.1.1                       Alcohol dehydrogenase       645.4
# 1     EC:1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase      1650.0
# 2     EC:1.1.1.108                   Carnitine 3-dehydrogenase        21.2
# 3      EC:1.1.1.11                D-arabinitol 4-dehydrogenase        81.0
# 4     EC:1.1.1.132                 GDP-mannose 6-dehydrogenase        21.2
# ...            ...                                         ...         ...
# 1307    EC:6.5.1.4     RNA 3'-terminal-phosphate cyclase (ATP)        29.2
# 1308    EC:6.5.1.6                  DNA ligase (ATP or NAD(+))       299.0
# 1309    EC:6.5.1.7                DNA ligase (ATP, ADP or GTP)       299.0
# 1310    EC:6.6.1.1                         Magnesium chelatase        26.2
# 1311    EC:6.6.1.2                            Cobaltochelatase       560.2
#
#       sampleID_1a  sampleID_2  sampleID_2a class subclass
# 0           402.8      874.24       457.92     1      1.1
# 1          1301.0     2171.84      1572.32     1      1.1
# 2             2.4       11.20        12.80     1      1.1
# 3             0.0       99.00         0.00     1      1.1
# 4             2.4       11.20        12.80     1      1.1
# ...           ...         ...          ...   ...      ...
# 1307         29.4       22.20        42.80     6      6.5
# 1308         17.0      501.00        24.00     6      6.5
# 1309         17.0      501.00        24.00     6      6.5
# 1310          2.4       24.20        12.80     6      6.6
# 1311         53.4     1070.20        36.80     6      6.6
#
# [1312 rows x 8 columns]

# %%
# Add class and subclass names
ec = ec.merge(class_df, how="left", on="class")
ec = ec.merge(subclass_df, how="left", on="subclass")
ec
# Out:
#           function                                 description  sampleID_1  \
# 0       EC:1.1.1.1                       Alcohol dehydrogenase       645.4
# 1     EC:1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase      1650.0
# 2     EC:1.1.1.108                   Carnitine 3-dehydrogenase        21.2
# 3      EC:1.1.1.11                D-arabinitol 4-dehydrogenase        81.0
# 4     EC:1.1.1.132                 GDP-mannose 6-dehydrogenase        21.2
# ...            ...                                         ...         ...
# 1307    EC:6.5.1.4     RNA 3'-terminal-phosphate cyclase (ATP)        29.2
# 1308    EC:6.5.1.6                  DNA ligase (ATP or NAD(+))       299.0
# 1309    EC:6.5.1.7                DNA ligase (ATP, ADP or GTP)       299.0
# 1310    EC:6.6.1.1                         Magnesium chelatase        26.2
# 1311    EC:6.6.1.2                            Cobaltochelatase       560.2
#
#       sampleID_1a  sampleID_2  sampleID_2a class subclass        class_name  \
# 0           402.8      874.24       457.92     1      1.1  Oxidoreductases.
# 1          1301.0     2171.84      1572.32     1      1.1  Oxidoreductases.
# 2             2.4       11.20        12.80     1      1.1  Oxidoreductases.
# 3             0.0       99.00         0.00     1      1.1  Oxidoreductases.
# 4             2.4       11.20        12.80     1      1.1  Oxidoreductases.
# ...           ...         ...          ...   ...      ...               ...
# 1307         29.4       22.20        42.80     6      6.5          Ligases.
# 1308         17.0      501.00        24.00     6      6.5          Ligases.
# 1309         17.0      501.00        24.00     6      6.5          Ligases.
# 1310          2.4       24.20        12.80     6      6.6          Ligases.
# 1311         53.4     1070.20        36.80     6      6.6          Ligases.
#
#                              subclass_name
# 0     Acting on the CH-OH group of donors.
# 1     Acting on the CH-OH group of donors.
# 2     Acting on the CH-OH group of donors.
# 3     Acting on the CH-OH group of donors.
# 4     Acting on the CH-OH group of donors.
# ...                                    ...
# 1307       Forming phosphoric ester bonds.
# 1308       Forming phosphoric ester bonds.
# 1309       Forming phosphoric ester bonds.
# 1310         Forming nitrogen-metal bonds.
# 1311         Forming nitrogen-metal bonds.
#
# [1312 rows x 10 columns]

# %%
# Summarize by class and subclass
numeric_cols = ec.columns[2:-4]  # define only sample cols
print(numeric_cols)
ec_summarized = ec.groupby(["class", "class_name", "subclass", "subclass_name"])[numeric_cols].sum().reset_index()
ec_summarized
# Out:
# Index(['sampleID_1', 'sampleID_1a', 'sampleID_2', 'sampleID_2a'], dtype='object')
#    class        class_name subclass  \
# 0      1  Oxidoreductases.      1.1
# 1      1  Oxidoreductases.      1.2
# 2      1  Oxidoreductases.      1.3
# 3      1  Oxidoreductases.      1.4
# 4      1  Oxidoreductases.      1.5
# 5      1  Oxidoreductases.      1.6
# 6      1  Oxidoreductases.      1.7
# 7      1  Oxidoreductases.      1.8
# 8      1  Oxidoreductases.      1.9
# 9      2     Transferases.      2.1
# 10     2     Transferases.      2.2
# 11     2     Transferases.      2.3
# 12     2     Transferases.      2.4
# 13     2     Transferases.      2.5
# 14     2     Transferases.      2.6
# 15     2     Transferases.      2.7
# 16     2     Transferases.      2.8
# 17     2     Transferases.      2.9
# 18     3       Hydrolases.      3.1
# 19     3       Hydrolases.      3.2
# 20     3       Hydrolases.      3.3
# 21     3       Hydrolases.      3.4
# 22     3       Hydrolases.      3.5
# 23     3       Hydrolases.      3.6
# 24     3       Hydrolases.      3.7
# 25     3       Hydrolases.      3.8
# 26     4           Lyases.      4.1
# 27     4           Lyases.      4.2
# 28     4           Lyases.      4.3
# 29     4           Lyases.      4.4
# 30     4           Lyases.      4.6
# 31     5       Isomerases.      5.1
# 32     5       Isomerases.      5.2
# 33     5       Isomerases.      5.3
# 34     5       Isomerases.      5.4
# 35     5       Isomerases.      5.5
# 36     6          Ligases.      6.1
# 37     6          Ligases.      6.2
# 38     6          Ligases.      6.3
# 39     6          Ligases.      6.4
# 40     6          Ligases.      6.5
# 41     6          Ligases.      6.6
#
#                                         subclass_name  sampleID_1  \
# 0                Acting on the CH-OH group of donors.    20981.25
# 1      Acting on the aldehyde or oxo group of donors.    10738.50
# 2                Acting on the CH-CH group of donors.     8920.80
# 3               Acting on the CH-NH2 group of donors.     4388.95
# 4                Acting on the CH-NH group of donors.     3537.35
# 5                            Acting on NADH or NADPH.     7593.70
# 6    Acting on other nitrogenous compounds as donors.     3598.80
# 7                 Acting on a sulfur group of donors.     5307.90
# 8                   Acting on a heme group of donors.     1923.20
# 9                     Transferring one-carbon groups.    25847.00
# 10           Transferring aldehyde or ketonic groups.     3217.15
# 11                                  Acyltransferases.    19515.20
# 12                              Glycosyltransferases.    10112.55
# 13  Transferring alkyl or aryl groups, other than ...    14674.75
# 14                   Transferring nitrogenous groups.     7576.45
# 15         Transferring phosphorus-containing groups.    48303.65
# 16             Transferring sulfur-containing groups.     6508.70
# 17           Transferring selenium-containing groups.       46.00
# 18                             Acting on ester bonds.    21911.95
# 19                                      Glycosylases.     3832.95
# 20                             Acting on ether bonds.      567.15
# 21              Acting on peptide bonds (peptidases).    10262.25
# 22  Acting on carbon-nitrogen bonds, other than pe...    16034.65
# 23                         Acting on acid anhydrides.    21233.70
# 24                     Acting on carbon-carbon bonds.     1386.75
# 25                            Acting on halide bonds.      380.20
# 26                              Carbon-carbon lyases.    15310.45
# 27                              Carbon-oxygen lyases.    18009.45
# 28                            Carbon-nitrogen lyases.     3924.15
# 29                              Carbon-sulfur lyases.     1401.05
# 30                          Phosphorus-oxygen lyases.      855.15
# 31                          Racemases and epimerases.     5537.55
# 32                              Cis-trans-isomerases.     4067.45
# 33                    Intramolecular oxidoreductases.     6470.60
# 34                       Intramolecular transferases.    10468.75
# 35                             Intramolecular lyases.       99.90
# 36                       Forming carbon-oxygen bonds.    10157.90
# 37                       Forming carbon-sulfur bonds.     4215.70
# 38                     Forming carbon-nitrogen bonds.    21566.95
# 39                       Forming carbon-carbon bonds.     2887.25
# 40                    Forming phosphoric ester bonds.     1571.75
# 41                      Forming nitrogen-metal bonds.      586.40
#
#     sampleID_1a  sampleID_2  sampleID_2a
# 0       11285.0    29349.77     13763.62
# 1        8318.0    15864.96      9738.10
# 2        4535.6    13340.67      5260.47
# 3        3156.4     6335.26      3727.69
# 4        1463.2     5168.66      1811.29
# 5        5342.4    11451.50      6097.24
# 6        1197.6     5964.31      1287.19
# 7        2748.8     8102.01      3239.39
# 8         384.4     2967.20       444.80
# 9       17115.0    39333.75     19657.51
# 10       2803.8     5012.95      3131.50
# 11      10254.4    28748.64     12115.00
# 12       9894.6    15275.38     11061.05
# 13      10294.0    22532.26     11611.49
# 14       5159.4    11250.04      5930.17
# 15      37427.8    73007.36     42238.73
# 16       3881.4     9720.18      4405.92
# 17        162.0       59.00       183.00
# 18      11782.4    31951.55     13767.22
# 19       1044.4     5169.75      1350.70
# 20        456.8      843.11       520.18
# 21       6528.0    14883.50      7695.03
# 22       7600.8    22647.95      9504.60
# 23      12839.4    31578.19     14789.85
# 24        183.0     2066.71       301.58
# 25         19.4      630.20        12.80
# 26       9518.4    22480.23     11130.80
# 27      12357.4    26898.76     14179.77
# 28       2077.8     5458.80      2582.83
# 29        335.6     2178.60       405.61
# 30        770.8     1350.11       843.18
# 31       4339.6     8241.04      4830.75
# 32       1805.4     6092.34      2172.51
# 33       4234.2     9945.12      4796.36
# 34       6567.0    15930.91      7475.18
# 35        157.8       91.49       211.43
# 36       9279.8    15565.02     10361.36
# 37       1892.4     6597.13      2156.95
# 38      17590.4    32541.32     19974.59
# 39       1460.0     4361.31      1652.40
# 40       1030.0     2472.71      1206.58
# 41         55.8     1094.40        49.60

# %%
# Melt the DataFrame to long format
ec_long = ec_summarized.melt(
    id_vars=["class", "class_name", "subclass", "subclass_name"],
    var_name="sample",
    value_name="abundance"
)
ec_long
# Out:
#     class        class_name subclass  \
# 0       1  Oxidoreductases.      1.1
# 1       1  Oxidoreductases.      1.2
# 2       1  Oxidoreductases.      1.3
# 3       1  Oxidoreductases.      1.4
# 4       1  Oxidoreductases.      1.5
# ..    ...               ...      ...
# 163     6          Ligases.      6.2
# 164     6          Ligases.      6.3
# 165     6          Ligases.      6.4
# 166     6          Ligases.      6.5
# 167     6          Ligases.      6.6
#
#                                       subclass_name       sample  abundance
# 0              Acting on the CH-OH group of donors.   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors.   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors.   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors.   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors.   sampleID_1    3537.35
# ..                                              ...          ...        ...
# 163                    Forming carbon-sulfur bonds.  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds.  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds.  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds.  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds.  sampleID_2a      49.60
#
# [168 rows x 6 columns]

# %%
# Add condition/treatment metadata
ec_long_meta = ec_long.merge(meta[["ID","treatment1"]], how="left", left_on="sample", right_on="ID").drop("ID", axis=1)
for colname in ["class_name", "subclass_name"]:
    ec_long_meta[colname] = ec_long_meta[colname].str.replace(".","")
ec_long_meta
# Out:
#     class       class_name subclass  \
# 0       1  Oxidoreductases      1.1
# 1       1  Oxidoreductases      1.2
# 2       1  Oxidoreductases      1.3
# 3       1  Oxidoreductases      1.4
# 4       1  Oxidoreductases      1.5
# ..    ...              ...      ...
# 163     6          Ligases      6.2
# 164     6          Ligases      6.3
# 165     6          Ligases      6.4
# 166     6          Ligases      6.5
# 167     6          Ligases      6.6
#
#                                      subclass_name       sample  abundance  \
# 0              Acting on the CH-OH group of donors   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors   sampleID_1    3537.35
# ..                                             ...          ...        ...
# 163                    Forming carbon-sulfur bonds  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds  sampleID_2a      49.60
#
#     treatment1
# 0            b
# 1            b
# 2            b
# 3            b
# 4            b
# ..         ...
# 163          a
# 164          a
# 165          a
# 166          a
# 167          a
#
# [168 rows x 7 columns]

# %%
print("Number of classes:", ec_long_meta["class"].nunique())
print("Number of subclasses:", ec_long_meta["subclass"].nunique())
# Out:
# Number of classes: 6
# Number of subclasses: 42

# %%
# SETTING UP COLOURS FOR THE BOXPLOT CLASSES

# Get unique groups in the order they appear
group_labels = ec_long_meta["class_name"].unique().tolist()

# Keep only unique (class_name, subclass) pairs
unique_groups = ec_long_meta[["class_name", "subclass"]].drop_duplicates().reset_index()

# Compute bounds
group_bounds = (
    unique_groups.groupby("class_name")["index"]
    .apply(lambda x: (x.min(), x.max() + 1))
    .tolist()
)

group_colors = ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C', '#FB9A99', '#E31A1C']  # Soft pastel colors

print("Group Labels:", group_labels)
print("Group Bounds:", group_bounds)
print("Group Colours:", group_colors)
# Out:
# Group Labels: ['Oxidoreductases', 'Transferases', 'Hydrolases', 'Lyases', 'Isomerases', 'Ligases']
# Group Bounds: [(np.int64(18), np.int64(26)), (np.int64(31), np.int64(36)), (np.int64(36), np.int64(42)), (np.int64(26), np.int64(31)), (np.int64(0), np.int64(9)), (np.int64(9), np.int64(18))]
# Group Colours: ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C', '#FB9A99', '#E31A1C']

# %%
y_order = unique_groups["class_name"].unique() # not used, just in case

# %%
ec_long_meta
# Out:
#     class       class_name subclass  \
# 0       1  Oxidoreductases      1.1
# 1       1  Oxidoreductases      1.2
# 2       1  Oxidoreductases      1.3
# 3       1  Oxidoreductases      1.4
# 4       1  Oxidoreductases      1.5
# ..    ...              ...      ...
# 163     6          Ligases      6.2
# 164     6          Ligases      6.3
# 165     6          Ligases      6.4
# 166     6          Ligases      6.5
# 167     6          Ligases      6.6
#
#                                      subclass_name       sample  abundance  \
# 0              Acting on the CH-OH group of donors   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors   sampleID_1    3537.35
# ..                                             ...          ...        ...
# 163                    Forming carbon-sulfur bonds  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds  sampleID_2a      49.60
#
#     treatment1
# 0            b
# 1            b
# 2            b
# 3            b
# 4            b
# ..         ...
# 163          a
# 164          a
# 165          a
# 166          a
# 167          a
#
# [168 rows x 7 columns]

# %%
# Create figure
fig,ax = plt.subplots(figsize=(14, 16))

# Remove whitespace in plot
category_positions = range(len(ec_long_meta['class'].unique()))
ax.set_ylim(min(category_positions), max(category_positions))

# Seaborn boxplot
sns.boxplot(x="abundance",
            y="subclass_name", 
            hue="treatment1", 
            data=ec_long_meta, 
            flierprops=dict(marker='o', markerfacecolor='black', markersize=0.75),
            ax=ax
           )

# Add background colors for each module (shade horizontal regions along y-axis)
for i, (group, (y_start, y_end), color) in enumerate(zip(group_labels, group_bounds, group_colors)):
    ax.axhspan(y_start - 0.5, y_end - 0.5, color=color, alpha=0.3, zorder=0)  # Background color
    ax.text(ax.get_xlim()[1], (y_start + y_end) / 2 - 0.5, group, 
            ha='left', va='center', fontsize=12, fontweight='bold')

# Title and labels
plt.title('Enzyme Commission Relative Abundances by Treatment', fontsize=16, fontweight='bold')
plt.xlabel('Abundance Value', fontweight='bold')
plt.ylabel('Enzyme Commission Sublass', fontweight='bold')
plt.legend(title='Condition', loc='lower right')

# Save plot
plt.savefig("results/picrust/picrust_ec.pdf")
plt.show()

# %% [markdown]
# #### To do:
# - Order subgroups within groups by abundance

# %% [markdown]
# ### MetaCyc Pathway Analysis
# On hold as MetaCyc groups require license to be accessed

# %%
# Load Data
meta = pd.read_csv(f"{cwd}/input/{dir}/Metadata.tsv", sep="\t")
metacyc = pd.read_csv(f"{cwd}/input/{dir}/picrust/{metacyc_filename}", sep="\t", header=0)

# %%
meta
# Out:
#             ID treatment1 bad3 bad4  bad5  num6  num7 mix8 bad9 badpairwise10  \
# 0   sampleID_1          b    a    a   NaN     1   NaN    2    a           NaN
# 1   sampleID_2          b    a  NaN   NaN     2   1.0    2    b             2
# 2  sampleID_1a          a    a  NaN   NaN     3   NaN    a    c             2
# 3  sampleID_2a          a    a    a   NaN     1   NaN    a    d             a
#
#   materialSampleID target_gene
# 0       ERS3508481    SSU rRNA
# 1       ERS3508482    SSU rRNA
# 2       ERS3508483    SSU rRNA
# 3       ERS3508484    SSU rRNA

# %%
metacyc["pathway"].unique()
# Out:
# array(['1CMET2-PWY', '3-HYDROXYPHENYLACETATE-DEGRADATION-PWY',
#        'ANAEROFRUCAT-PWY', 'ANAGLYCOLYSIS-PWY', 'ARG+POLYAMINE-SYN',
#        'ARGORNPROST-PWY', 'ARGSYN-PWY', 'ARGSYNBSUB-PWY', 'ARO-PWY',
#        'ASPASN-PWY', 'AST-PWY', 'BIOTIN-BIOSYNTHESIS-PWY',
#        'BRANCHED-CHAIN-AA-SYN-PWY', 'CALVIN-PWY',
#        'CATECHOL-ORTHO-CLEAVAGE-PWY', 'COA-PWY', 'COBALSYN-PWY',
#        'CODH-PWY', 'COLANSYN-PWY', 'COMPLETE-ARO-PWY', 'CRNFORCAT-PWY',
#        'DAPLYSINESYN-PWY', 'DENITRIFICATION-PWY', 'DENOVOPURINE2-PWY',
#        'DHGLUCONATE-PYR-CAT-PWY', 'DTDPRHAMSYN-PWY', 'FAO-PWY',
#        'FASYN-ELONG-PWY', 'FASYN-INITIAL-PWY', 'FERMENTATION-PWY',
#        'FOLSYN-PWY', 'GALLATE-DEGRADATION-I-PWY', 'GLUCONEO-PWY',
#        'GLUCOSE1PMETAB-PWY', 'GLUTORN-PWY', 'GLYCOCAT-PWY',
#        'GLYCOGENSYNTH-PWY', 'GLYCOLYSIS', 'GLYCOLYSIS-E-D',
#        'GLYCOLYSIS-TCA-GLYOX-BYPASS', 'GLYOXYLATE-BYPASS',
#        'HEME-BIOSYNTHESIS-II', 'HEMESYN2-PWY', 'HISDEG-PWY',
#        'HISTSYN-PWY', 'HOMOSER-METSYN-PWY', 'HSERMETANA-PWY',
#        'ILEUSYN-PWY', 'LEU-DEG2-PWY', 'MET-SAM-PWY', 'METH-ACETATE-PWY',
#        'METHYLGALLATE-DEGRADATION-PWY', 'NAD-BIOSYNTHESIS-II',
#        'NAGLIPASYN-PWY', 'NONMEVIPP-PWY', 'NONOXIPENT-PWY',
#        'OANTIGEN-PWY', 'P101-PWY', 'P105-PWY', 'P108-PWY', 'P122-PWY',
#        'P124-PWY', 'P125-PWY', 'P161-PWY', 'P184-PWY', 'P221-PWY',
#        'P23-PWY', 'P281-PWY', 'P4-PWY', 'P42-PWY', 'P562-PWY',
#        'PANTO-PWY', 'PANTOSYN-PWY', 'PENTOSE-P-PWY',
#        'PEPTIDOGLYCANSYN-PWY', 'PHOSLIPSYN-PWY', 'POLYAMINSYN3-PWY',
#        'POLYAMSYN-PWY', 'POLYISOPRENSYN-PWY', 'PPGPPMET-PWY',
#        'PROTOCATECHUATE-ORTHO-CLEAVAGE-PWY', 'PRPP-PWY', 'PWY-1269',
#        'PWY-181', 'PWY-2941', 'PWY-2942', 'PWY-3001', 'PWY-3781',
#        'PWY-4361', 'PWY-4984', 'PWY-5005', 'PWY-5022', 'PWY-5028',
#        'PWY-5097', 'PWY-5100', 'PWY-5101', 'PWY-5103', 'PWY-5104',
#        'PWY-5121', 'PWY-5154', 'PWY-5180', 'PWY-5181', 'PWY-5182',
#        'PWY-5188', 'PWY-5189', 'PWY-5304', 'PWY-5345', 'PWY-5347',
#        'PWY-5384', 'PWY-5415', 'PWY-5417', 'PWY-5419', 'PWY-5420',
#        'PWY-5430', 'PWY-5431', 'PWY-5484', 'PWY-5505', 'PWY-5509',
#        'PWY-5654', 'PWY-5659', 'PWY-5667', 'PWY-5676', 'PWY-5686',
#        'PWY-5695', 'PWY-5705', 'PWY-5747', 'PWY-5855', 'PWY-5856',
#        'PWY-5857', 'PWY-5913', 'PWY-5918', 'PWY-5920', 'PWY-5941',
#        'PWY-5973', 'PWY-5989', 'PWY-6071', 'PWY-6121', 'PWY-6122',
#        'PWY-6123', 'PWY-6125', 'PWY-6126', 'PWY-6147', 'PWY-6151',
#        'PWY-6163', 'PWY-6182', 'PWY-6185', 'PWY-621', 'PWY-6263',
#        'PWY-6269', 'PWY-6277', 'PWY-6282', 'PWY-6317', 'PWY-6353',
#        'PWY-6385', 'PWY-6386', 'PWY-6387', 'PWY-6396', 'PWY-6467',
#        'PWY-6478', 'PWY-6519', 'PWY-6545', 'PWY-6562', 'PWY-6608',
#        'PWY-6609', 'PWY-6612', 'PWY-6628', 'PWY-6630', 'PWY-6700',
#        'PWY-6703', 'PWY-6708', 'PWY-6737', 'PWY-6749', 'PWY-6892',
#        'PWY-6897', 'PWY-6969', 'PWY-7090', 'PWY-7094', 'PWY-7111',
#        'PWY-7184', 'PWY-7187', 'PWY-7196', 'PWY-7197', 'PWY-7199',
#        'PWY-7200', 'PWY-7208', 'PWY-7211', 'PWY-7219', 'PWY-7220',
#        'PWY-7221', 'PWY-7222', 'PWY-7228', 'PWY-7229', 'PWY-7234',
#        'PWY-7237', 'PWY-7254', 'PWY-7315', 'PWY-7323', 'PWY-7328',
#        'PWY-7347', 'PWY-7371', 'PWY-7374', 'PWY-7376', 'PWY-7392',
#        'PWY-7400', 'PWY-7431', 'PWY-7527', 'PWY-7539', 'PWY-7560',
#        'PWY-7663', 'PWY-7664', 'PWY-841', 'PWY0-1061', 'PWY0-1241',
#        'PWY0-1261', 'PWY0-1296', 'PWY0-1297', 'PWY0-1298', 'PWY0-1319',
#        'PWY0-1338', 'PWY0-1415', 'PWY0-1479', 'PWY0-1586', 'PWY0-162',
#        'PWY0-166', 'PWY0-321', 'PWY0-42', 'PWY0-781', 'PWY0-845',
#        'PWY0-862', 'PWY4FS-7', 'PWY4FS-8', 'PWYG-321', 'PYRIDNUCSAL-PWY',
#        'PYRIDNUCSYN-PWY', 'PYRIDOXSYN-PWY', 'REDCITCYC', 'RIBOSYN2-PWY',
#        'SALVADEHYPOX-PWY', 'SER-GLYSYN-PWY', 'SO4ASSIM-PWY', 'SUCSYN-PWY',
#        'SULFATE-CYS-PWY', 'TCA', 'TCA-GLYOX-BYPASS', 'THISYN-PWY',
#        'THRESYN-PWY', 'TRNA-CHARGING-PWY', 'TRPSYN-PWY', 'TYRFUMCAT-PWY',
#        'UBISYN-PWY', 'UDPNAGSYN-PWY', 'VALSYN-PWY'], dtype=object)

# %%
metacyc["description"].unique()
# Out:
# array(['N10-formyl-tetrahydrofolate biosynthesis',
#        '4-hydroxyphenylacetate degradation', 'homolactic fermentation',
#        'glycolysis III (from glucose)',
#        'superpathway of arginine and polyamine biosynthesis',
#        'arginine, ornithine and proline interconversion',
#        'L-arginine biosynthesis I (via L-ornithine)',
#        'L-arginine biosynthesis II (acetyl cycle)',
#        'chorismate biosynthesis I',
#        'superpathway of L-aspartate and L-asparagine biosynthesis',
#        'L-arginine degradation II (AST pathway)', 'biotin biosynthesis I',
#        'superpathway of branched amino acid biosynthesis',
#        'Calvin-Benson-Bassham cycle',
#        'catechol degradation to &beta;-ketoadipate',
#        'coenzyme A biosynthesis I',
#        'adenosylcobalamin salvage from cobinamide I',
#        'reductive acetyl coenzyme A pathway',
#        'colanic acid building blocks biosynthesis',
#        'superpathway of aromatic amino acid biosynthesis',
#        'creatinine degradation I', 'L-lysine biosynthesis I',
#        'nitrate reduction I (denitrification)',
#        'superpathway of purine nucleotides de novo biosynthesis II',
#        'glucose degradation (oxidative)',
#        'dTDP-L-rhamnose biosynthesis I', 'fatty acid &beta;-oxidation I',
#        'fatty acid elongation -- saturated',
#        'superpathway of fatty acid biosynthesis initiation (E. coli)',
#        'mixed acid fermentation',
#        'superpathway of tetrahydrofolate biosynthesis and salvage',
#        'gallate degradation II', 'gluconeogenesis I',
#        'glucose and glucose-1-phosphate degradation',
#        'L-ornithine biosynthesis', 'glycogen degradation I (bacterial)',
#        'glycogen biosynthesis I (from ADP-D-Glucose)',
#        'glycolysis I (from glucose 6-phosphate)',
#        'superpathway of glycolysis and Entner-Doudoroff',
#        'superpathway of glycolysis, pyruvate dehydrogenase, TCA, and glyoxylate bypass',
#        'glyoxylate cycle', 'heme biosynthesis I (aerobic)',
#        'heme biosynthesis II (anaerobic)', 'L-histidine degradation I',
#        'L-histidine biosynthesis', 'L-methionine biosynthesis I',
#        'L-methionine biosynthesis III',
#        'L-isoleucine biosynthesis I (from threonine)',
#        'L-leucine degradation I',
#        'superpathway of S-adenosyl-L-methionine biosynthesis',
#        'methanogenesis from acetate', 'methylgallate degradation',
#        'NAD salvage pathway II', 'lipid IVA biosynthesis',
#        'methylerythritol phosphate pathway I',
#        'pentose phosphate pathway (non-oxidative branch)',
#        'O-antigen building blocks biosynthesis (E. coli)',
#        'ectoine biosynthesis',
#        'TCA cycle IV (2-oxoglutarate decarboxylase)',
#        'pyruvate fermentation to propanoate I',
#        'heterolactic fermentation', 'Bifidobacterium shunt',
#        'superpathway of (R,R)-butanediol biosynthesis',
#        'acetylene degradation',
#        'protocatechuate degradation I (meta-cleavage pathway)',
#        'octane oxidation', 'reductive TCA cycle I',
#        '3-phenylpropanoate degradation',
#        'superpathway of L-lysine, L-threonine and L-methionine biosynthesis I',
#        'incomplete reductive TCA cycle', 'myo-inositol degradation I',
#        'phosphopantothenate biosynthesis I',
#        'pantothenate and coenzyme A biosynthesis I',
#        'pentose phosphate pathway',
#        'peptidoglycan biosynthesis I (meso-diaminopimelate containing)',
#        'superpathway of phospholipid biosynthesis I (bacteria)',
#        'superpathway of polyamine biosynthesis II',
#        'superpathway of polyamine biosynthesis I',
#        'polyisoprenoid biosynthesis (E. coli)', 'ppGpp biosynthesis',
#        'protocatechuate degradation II (ortho-cleavage pathway)',
#        'superpathway of histidine, purine, and pyrimidine biosynthesis',
#        'CMP-3-deoxy-D-manno-octulosonate biosynthesis I',
#        'photorespiration', 'L-lysine biosynthesis II',
#        'L-lysine biosynthesis III',
#        'superpathway of L-isoleucine biosynthesis I',
#        'aerobic respiration I (cytochrome c)',
#        'S-methyl-5-thio-&alpha;-D-ribose 1-phosphate degradation',
#        'urea cycle', 'biotin biosynthesis II',
#        '4-aminobutanoate degradation V', 'L-histidine degradation II',
#        'L-lysine biosynthesis VI',
#        'pyruvate fermentation to acetate and lactate II',
#        'L-isoleucine biosynthesis II', 'L-isoleucine biosynthesis III',
#        'L-isoleucine biosynthesis IV',
#        'superpathway of geranylgeranyl diphosphate biosynthesis II (via MEP)',
#        'L-arginine biosynthesis III (via N-acetyl-L-citrulline)',
#        'toluene degradation I (aerobic) (via o-cresol)',
#        'toluene degradation III (aerobic) (via p-cresol)',
#        'toluene degradation II (aerobic) (via 4-methylcatechol)',
#        'tetrapyrrole biosynthesis I (from glutamate)',
#        'tetrapyrrole biosynthesis II (from glycine)',
#        'superpathway of sulfur oxidation (Acidianus ambivalens)',
#        'superpathway of L-methionine biosynthesis (by sulfhydrylation)',
#        'superpathway of L-methionine biosynthesis (transsulfuration)',
#        'sucrose degradation IV (sucrose phosphorylase)',
#        'catechol degradation I (meta-cleavage pathway)',
#        'catechol degradation III (ortho-cleavage pathway)',
#        'catechol degradation to 2-oxopent-4-enoate II',
#        'catechol degradation II (meta-cleavage pathway)',
#        'meta cleavage pathway of aromatic compounds',
#        'aromatic compounds degradation via &beta;-ketoadipate',
#        'glycolysis II (from fructose 6-phosphate)',
#        'L-glutamate and L-glutamine biosynthesis',
#        'adenosylcobalamin biosynthesis from cobyrinate a,c-diamide I',
#        '2-amino-3-carboxymuconate semialdehyde degradation to 2-oxopentenoate',
#        'GDP-mannose biosynthesis', 'CDP-diacylglycerol biosynthesis I',
#        'acetyl-CoA fermentation to butanoate II', 'UMP biosynthesis',
#        "urate biosynthesis/inosine 5'-phosphate degradation",
#        'allantoin degradation to glyoxylate III',
#        '2-methylcitrate cycle II',
#        'ubiquinol-7 biosynthesis (prokaryotic)',
#        'ubiquinol-9 biosynthesis (prokaryotic)',
#        'ubiquinol-10 biosynthesis (prokaryotic)',
#        'TCA cycle VI (obligate autotrophs)',
#        'superpathay of heme biosynthesis from glutamate',
#        'superpathway of heme biosynthesis from glycine',
#        'glycogen degradation II (eukaryotic)',
#        'cis-vaccenate biosynthesis',
#        'stearate biosynthesis II (bacteria and plants)',
#        'superpathway of phenylethylamine degradation',
#        '5-aminoimidazole ribonucleotide biosynthesis I',
#        '5-aminoimidazole ribonucleotide biosynthesis II',
#        "inosine-5'-phosphate biosynthesis I",
#        'superpathway of guanosine nucleotides de novo biosynthesis II',
#        'superpathway of adenosine nucleotides de novo biosynthesis II',
#        '6-hydroxymethyl-dihydropterin diphosphate biosynthesis I',
#        'S-adenosyl-L-methionine cycle I',
#        'chorismate biosynthesis from 3-dehydroquinate',
#        'superpathway of salicylate degradation',
#        '4-methylcatechol degradation (ortho cleavage)',
#        'sucrose degradation III (sucrose invertase)',
#        'superpathway of menaquinol-8 biosynthesis II',
#        'adenosylcobalamin salvage from cobinamide II',
#        'superpathway of 5-aminoimidazole ribonucleotide biosynthesis',
#        'palmitoleate biosynthesis I (from (5Z)-dodec-5-enoate)',
#        'galactose degradation I (Leloir pathway)',
#        'purine nucleotides degradation II (aerobic)',
#        'peptidoglycan biosynthesis III (mycobacteria)',
#        'UDP-N-acetylmuramoyl-pentapeptide biosynthesis II (lysine-containing)',
#        'UDP-N-acetylmuramoyl-pentapeptide biosynthesis I (meso-diaminopimelate containing)',
#        'superpathway of 2,3-butanediol biosynthesis',
#        'Kdo transfer to lipid IVA III (Chlamydia)',
#        'GDP-D-glycero-&alpha;-D-manno-heptose biosynthesis',
#        '8-amino-7-oxononanoate biosynthesis I',
#        'pyrimidine deoxyribonucleotides de novo biosynthesis III',
#        'norspermidine biosynthesis',
#        'guanosine nucleotides degradation III',
#        'adenine and adenosine salvage III',
#        'superpathway of tetrahydrofolate biosynthesis',
#        'superpathway of L-phenylalanine biosynthesis',
#        'superpathway of L-tyrosine biosynthesis',
#        'queuosine biosynthesis', 'preQ0 biosynthesis',
#        'ubiquinol-8 biosynthesis (prokaryotic)', 'starch degradation V',
#        'CMP-legionaminate biosynthesis I',
#        'thiazole biosynthesis I (E. coli)', 'thiamin salvage II',
#        'TCA cycle V (2-oxoglutarate:ferredoxin oxidoreductase)',
#        'UDP-2,3-diacetamido-2,3-dideoxy-&alpha;-D-mannuronate biosynthesis',
#        'fatty acid salvage',
#        'pyruvate fermentation to isobutanol (engineered)',
#        'pyrimidine deoxyribonucleotides de novo biosynthesis I',
#        'pyrimidine deoxyribonucleotides de novo biosynthesis II',
#        'superpathway of pyrimidine ribonucleosides salvage',
#        'pyrimidine deoxyribonucleotide phosphorylation',
#        'pyrimidine deoxyribonucleosides salvage',
#        'superpathway of pyrimidine deoxyribonucleoside salvage',
#        'superpathway of pyrimidine nucleobases salvage',
#        'superpathway of pyrimidine deoxyribonucleotides de novo biosynthesis',
#        'adenosine ribonucleotides de novo biosynthesis',
#        'adenosine deoxyribonucleotides de novo biosynthesis II',
#        'guanosine ribonucleotides de novo biosynthesis',
#        'guanosine deoxyribonucleotides de novo biosynthesis II',
#        'superpathway of guanosine nucleotides de novo biosynthesis I',
#        'superpathway of adenosine nucleotides de novo biosynthesis I',
#        "inosine-5'-phosphate biosynthesis III",
#        'myo-, chiro- and scillo-inositol degradation',
#        'TCA cycle VII (acetate-producers)',
#        'dTDP-N-acetylthomosamine biosynthesis',
#        'superpathway of GDP-mannose-derived O-antigen building blocks biosynthesis',
#        'superpathway of UDP-glucose-derived O-antigen building blocks biosynthesis',
#        'sucrose biosynthesis III',
#        '1,4-dihydroxy-6-naphthoate biosynthesis II',
#        '1,4-dihydroxy-6-naphthoate biosynthesis I',
#        'cob(II)yrinate a,c-diamide biosynthesis II (late cobalt incorporation)',
#        'taxadiene biosynthesis (engineered)',
#        'L-arginine biosynthesis IV (archaebacteria)',
#        'aromatic biogenic amine degradation (bacteria)',
#        'L-methionine salvage cycle III',
#        '6-hydroxymethyl-dihydropterin diphosphate biosynthesis III (Chlamydia)',
#        'methylerythritol phosphate pathway II',
#        'gondoate biosynthesis (anaerobic)',
#        'oleate biosynthesis IV (anaerobic)',
#        'superpathway of purine nucleotides de novo biosynthesis I',
#        'superpathway of L-alanine biosynthesis',
#        'ADP-L-glycero-&beta;-D-manno-heptose biosynthesis',
#        'anhydromuropeptides recycling',
#        'purine ribonucleosides degradation',
#        'superpathway of purine deoxyribonucleosides degradation',
#        'superpathway of pyrimidine deoxyribonucleosides degradation',
#        'CDP-diacylglycerol biosynthesis II', 'polymyxin resistance',
#        'superpathway of heme biosynthesis from uroporphyrinogen-III',
#        'tRNA processing',
#        'peptidoglycan maturation (meso-diaminopimelate containing)',
#        'superpathway of pyrimidine ribonucleotides de novo biosynthesis',
#        'superpathway of pyrimidine deoxyribonucleotides de novo biosynthesis (E. coli)',
#        'phenylacetate degradation I (aerobic)', '2-methylcitrate cycle I',
#        'aspartate superpathway',
#        "superpathway of pyridoxal 5'-phosphate biosynthesis and salvage",
#        '(5Z)-dodec-5-enoate biosynthesis',
#        'phosphatidylglycerol biosynthesis I (plastidic)',
#        'phosphatidylglycerol biosynthesis II (non-plastidic)',
#        'mycolate biosynthesis', 'NAD salvage pathway I',
#        'NAD biosynthesis I (from aspartate)',
#        "pyridoxal 5'-phosphate biosynthesis I",
#        'TCA cycle VIII (helicobacter)',
#        'flavin biosynthesis I (bacteria and plants)',
#        'adenosine nucleotides degradation II',
#        'superpathway of L-serine and glycine biosynthesis I',
#        'sulfate reduction I (assimilatory)',
#        'sucrose biosynthesis I (from photosynthesis)',
#        'superpathway of sulfate assimilation and cysteine biosynthesis',
#        'TCA cycle I (prokaryotic)',
#        'superpathway of glyoxylate bypass and TCA',
#        'superpathway of thiamin diphosphate biosynthesis I',
#        'superpathway of L-threonine biosynthesis', 'tRNA charging',
#        'L-tryptophan biosynthesis', 'L-tyrosine degradation I',
#        'superpathway of ubiquinol-8 biosynthesis (prokaryotic)',
#        'UDP-N-acetyl-D-glucosamine biosynthesis I',
#        'L-valine biosynthesis'], dtype=object)

# %%
# Melt the DataFrame to long format
metacyc_long = metacyc.melt(
    id_vars=["pathway", "description"],
    var_name="sample",
    value_name="abundance"
)
metacyc_long
# Out:
#                                      pathway  \
# 0                                 1CMET2-PWY
# 1     3-HYDROXYPHENYLACETATE-DEGRADATION-PWY
# 2                           ANAEROFRUCAT-PWY
# 3                          ANAGLYCOLYSIS-PWY
# 4                          ARG+POLYAMINE-SYN
# ...                                      ...
# 1003                              TRPSYN-PWY
# 1004                           TYRFUMCAT-PWY
# 1005                              UBISYN-PWY
# 1006                           UDPNAGSYN-PWY
# 1007                              VALSYN-PWY
#
#                                             description       sample  \
# 0              N10-formyl-tetrahydrofolate biosynthesis   sampleID_1
# 1                    4-hydroxyphenylacetate degradation   sampleID_1
# 2                               homolactic fermentation   sampleID_1
# 3                         glycolysis III (from glucose)   sampleID_1
# 4     superpathway of arginine and polyamine biosynt...   sampleID_1
# ...                                                 ...          ...
# 1003                          L-tryptophan biosynthesis  sampleID_2a
# 1004                           L-tyrosine degradation I  sampleID_2a
# 1005  superpathway of ubiquinol-8 biosynthesis (prok...  sampleID_2a
# 1006          UDP-N-acetyl-D-glucosamine biosynthesis I  sampleID_2a
# 1007                              L-valine biosynthesis  sampleID_2a
#
#        abundance
# 0     480.810875
# 1      82.584877
# 2     406.358313
# 3     494.467916
# 4     113.672819
# ...          ...
# 1003  541.116259
# 1004   48.699543
# 1005  226.302670
# 1006  516.193182
# 1007  672.471701
#
# [1008 rows x 4 columns]
