# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %%
# Set paths and file names
cwd = os.getcwd()
dir = "pipeline-test"
kegg_filename = "KO_pred_metagenome_unstrat_descrip.tsv"
ec_filename = "EC_pred_metagenome_unstrat_descrip.tsv"
metacyc_filename = "METACYC_path_abun_unstrat_descrip.tsv"
meta_filename = "Metadata.tsv"
condition_col = "treatment1"

# %%
print(cwd)
# Out:
# /Users/camilla.callierotti/ampliseq-visualizations

# %%
# Load Data
meta = pd.read_csv(f"{cwd}/input/{dir}/Metadata.tsv", sep="\t")
ec = pd.read_csv(f"{cwd}/input/{dir}/picrust/{ec_filename}", sep="\t", header=0)

# %%
meta
# Out:
#             ID treatment1 bad3 bad4  bad5  num6  num7 mix8 bad9 badpairwise10  \
# 0   sampleID_1          b    a    a   NaN     1   NaN    2    a           NaN
# 1   sampleID_2          b    a  NaN   NaN     2   1.0    2    b             2
# 2  sampleID_1a          a    a  NaN   NaN     3   NaN    a    c             2
# 3  sampleID_2a          a    a    a   NaN     1   NaN    a    d             a
#
#   materialSampleID target_gene
# 0       ERS3508481    SSU rRNA
# 1       ERS3508482    SSU rRNA
# 2       ERS3508483    SSU rRNA
# 3       ERS3508484    SSU rRNA

# %%
# Load EC transcoding file
class_mapping = []
subclass_mapping = []

with open("input/general/enzclass.txt", "r") as f:
    for line in f:
        line = line.strip()

        # Match enzyme classes (e.g., "1. -.-  Oxidoreductases.")
        match_class = re.match(r"^(\d+)\.\s+-\.\s+-\.-\s+(.*)", line)

        # Match enzyme subclasses (e.g., "1. 1. -.-  Acting on the CH-OH group of donors.")
        match_subclass = re.match(r"^(\d+)\.\s*(\d+)\.\s+-\.-\s+(.*)", line)

        if match_class:
            class_mapping.append([match_class.group(1), match_class.group(2)])

        if match_subclass:
            subclass_code = f"{match_subclass.group(1)}.{match_subclass.group(2)}"
            subclass_mapping.append([subclass_code, match_subclass.group(3)])

# Convert to DataFrames
class_df = pd.DataFrame(class_mapping, columns=["class", "class_name"])
subclass_df = pd.DataFrame(subclass_mapping, columns=["subclass", "subclass_name"])

# %%
subclass_df
# Out:
#    subclass                                      subclass_name
# 0       1.1               Acting on the CH-OH group of donors.
# 1       1.2     Acting on the aldehyde or oxo group of donors.
# 2       1.3               Acting on the CH-CH group of donors.
# 3       1.4              Acting on the CH-NH2 group of donors.
# 4       1.5               Acting on the CH-NH group of donors.
# ..      ...                                                ...
# 74      7.2  Catalysing the translocation of inorganic cati...
# 75      7.3  Catalysing the translocation of inorganic anio...
# 76      7.4  Catalysing the translocation amino acids and p...
# 77      7.5  Catalysing the translocation carbohydrates and...
# 78      7.6   Catalysing the translocation of other compounds.
#
# [79 rows x 2 columns]

# %%
class_df
# Out:
#   class        class_name
# 0     1  Oxidoreductases.
# 1     2     Transferases.
# 2     3       Hydrolases.
# 3     4           Lyases.
# 4     5       Isomerases.
# 5     6          Ligases.
# 6     7     Translocases.

# %%
ec.dtypes
# Out:
# function        object
# description     object
# sampleID_1     float64
# sampleID_1a    float64
# sampleID_2     float64
# sampleID_2a    float64
# dtype: object

# %%
# Add class and subclass
ec["class"] = ec["function"].str.extract(r"EC:(\d)\.\d")
ec["subclass"] = ec["function"].str.extract(r"EC:(\d\.\d)\..")
ec
# Out:
#           function                                 description  sampleID_1  \
# 0       EC:1.1.1.1                       Alcohol dehydrogenase       645.4
# 1     EC:1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase      1650.0
# 2     EC:1.1.1.108                   Carnitine 3-dehydrogenase        21.2
# 3      EC:1.1.1.11                D-arabinitol 4-dehydrogenase        81.0
# 4     EC:1.1.1.132                 GDP-mannose 6-dehydrogenase        21.2
# ...            ...                                         ...         ...
# 1307    EC:6.5.1.4     RNA 3'-terminal-phosphate cyclase (ATP)        29.2
# 1308    EC:6.5.1.6                  DNA ligase (ATP or NAD(+))       299.0
# 1309    EC:6.5.1.7                DNA ligase (ATP, ADP or GTP)       299.0
# 1310    EC:6.6.1.1                         Magnesium chelatase        26.2
# 1311    EC:6.6.1.2                            Cobaltochelatase       560.2
#
#       sampleID_1a  sampleID_2  sampleID_2a class subclass
# 0           402.8      874.24       457.92     1      1.1
# 1          1301.0     2171.84      1572.32     1      1.1
# 2             2.4       11.20        12.80     1      1.1
# 3             0.0       99.00         0.00     1      1.1
# 4             2.4       11.20        12.80     1      1.1
# ...           ...         ...          ...   ...      ...
# 1307         29.4       22.20        42.80     6      6.5
# 1308         17.0      501.00        24.00     6      6.5
# 1309         17.0      501.00        24.00     6      6.5
# 1310          2.4       24.20        12.80     6      6.6
# 1311         53.4     1070.20        36.80     6      6.6
#
# [1312 rows x 8 columns]

# %%
# Add class and subclass names
ec = ec.merge(class_df, how="left", on="class")
ec = ec.merge(subclass_df, how="left", on="subclass")
ec
# Out:
#           function                                 description  sampleID_1  \
# 0       EC:1.1.1.1                       Alcohol dehydrogenase       645.4
# 1     EC:1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase      1650.0
# 2     EC:1.1.1.108                   Carnitine 3-dehydrogenase        21.2
# 3      EC:1.1.1.11                D-arabinitol 4-dehydrogenase        81.0
# 4     EC:1.1.1.132                 GDP-mannose 6-dehydrogenase        21.2
# ...            ...                                         ...         ...
# 1307    EC:6.5.1.4     RNA 3'-terminal-phosphate cyclase (ATP)        29.2
# 1308    EC:6.5.1.6                  DNA ligase (ATP or NAD(+))       299.0
# 1309    EC:6.5.1.7                DNA ligase (ATP, ADP or GTP)       299.0
# 1310    EC:6.6.1.1                         Magnesium chelatase        26.2
# 1311    EC:6.6.1.2                            Cobaltochelatase       560.2
#
#       sampleID_1a  sampleID_2  sampleID_2a class subclass        class_name  \
# 0           402.8      874.24       457.92     1      1.1  Oxidoreductases.
# 1          1301.0     2171.84      1572.32     1      1.1  Oxidoreductases.
# 2             2.4       11.20        12.80     1      1.1  Oxidoreductases.
# 3             0.0       99.00         0.00     1      1.1  Oxidoreductases.
# 4             2.4       11.20        12.80     1      1.1  Oxidoreductases.
# ...           ...         ...          ...   ...      ...               ...
# 1307         29.4       22.20        42.80     6      6.5          Ligases.
# 1308         17.0      501.00        24.00     6      6.5          Ligases.
# 1309         17.0      501.00        24.00     6      6.5          Ligases.
# 1310          2.4       24.20        12.80     6      6.6          Ligases.
# 1311         53.4     1070.20        36.80     6      6.6          Ligases.
#
#                              subclass_name
# 0     Acting on the CH-OH group of donors.
# 1     Acting on the CH-OH group of donors.
# 2     Acting on the CH-OH group of donors.
# 3     Acting on the CH-OH group of donors.
# 4     Acting on the CH-OH group of donors.
# ...                                    ...
# 1307       Forming phosphoric ester bonds.
# 1308       Forming phosphoric ester bonds.
# 1309       Forming phosphoric ester bonds.
# 1310         Forming nitrogen-metal bonds.
# 1311         Forming nitrogen-metal bonds.
#
# [1312 rows x 10 columns]

# %%
# Summarize by class and subclass
numeric_cols = ec.columns[2:-4]  # define only sample cols
print(numeric_cols)
ec_summarized = ec.groupby(["class", "class_name", "subclass", "subclass_name"])[numeric_cols].sum().reset_index()
ec_summarized
# Out:
# Index(['sampleID_1', 'sampleID_1a', 'sampleID_2', 'sampleID_2a'], dtype='object')
#    class        class_name subclass  \
# 0      1  Oxidoreductases.      1.1
# 1      1  Oxidoreductases.      1.2
# 2      1  Oxidoreductases.      1.3
# 3      1  Oxidoreductases.      1.4
# 4      1  Oxidoreductases.      1.5
# 5      1  Oxidoreductases.      1.6
# 6      1  Oxidoreductases.      1.7
# 7      1  Oxidoreductases.      1.8
# 8      1  Oxidoreductases.      1.9
# 9      2     Transferases.      2.1
# 10     2     Transferases.      2.2
# 11     2     Transferases.      2.3
# 12     2     Transferases.      2.4
# 13     2     Transferases.      2.5
# 14     2     Transferases.      2.6
# 15     2     Transferases.      2.7
# 16     2     Transferases.      2.8
# 17     2     Transferases.      2.9
# 18     3       Hydrolases.      3.1
# 19     3       Hydrolases.      3.2
# 20     3       Hydrolases.      3.3
# 21     3       Hydrolases.      3.4
# 22     3       Hydrolases.      3.5
# 23     3       Hydrolases.      3.6
# 24     3       Hydrolases.      3.7
# 25     3       Hydrolases.      3.8
# 26     4           Lyases.      4.1
# 27     4           Lyases.      4.2
# 28     4           Lyases.      4.3
# 29     4           Lyases.      4.4
# 30     4           Lyases.      4.6
# 31     5       Isomerases.      5.1
# 32     5       Isomerases.      5.2
# 33     5       Isomerases.      5.3
# 34     5       Isomerases.      5.4
# 35     5       Isomerases.      5.5
# 36     6          Ligases.      6.1
# 37     6          Ligases.      6.2
# 38     6          Ligases.      6.3
# 39     6          Ligases.      6.4
# 40     6          Ligases.      6.5
# 41     6          Ligases.      6.6
#
#                                         subclass_name  sampleID_1  \
# 0                Acting on the CH-OH group of donors.    20981.25
# 1      Acting on the aldehyde or oxo group of donors.    10738.50
# 2                Acting on the CH-CH group of donors.     8920.80
# 3               Acting on the CH-NH2 group of donors.     4388.95
# 4                Acting on the CH-NH group of donors.     3537.35
# 5                            Acting on NADH or NADPH.     7593.70
# 6    Acting on other nitrogenous compounds as donors.     3598.80
# 7                 Acting on a sulfur group of donors.     5307.90
# 8                   Acting on a heme group of donors.     1923.20
# 9                     Transferring one-carbon groups.    25847.00
# 10           Transferring aldehyde or ketonic groups.     3217.15
# 11                                  Acyltransferases.    19515.20
# 12                              Glycosyltransferases.    10112.55
# 13  Transferring alkyl or aryl groups, other than ...    14674.75
# 14                   Transferring nitrogenous groups.     7576.45
# 15         Transferring phosphorus-containing groups.    48303.65
# 16             Transferring sulfur-containing groups.     6508.70
# 17           Transferring selenium-containing groups.       46.00
# 18                             Acting on ester bonds.    21911.95
# 19                                      Glycosylases.     3832.95
# 20                             Acting on ether bonds.      567.15
# 21              Acting on peptide bonds (peptidases).    10262.25
# 22  Acting on carbon-nitrogen bonds, other than pe...    16034.65
# 23                         Acting on acid anhydrides.    21233.70
# 24                     Acting on carbon-carbon bonds.     1386.75
# 25                            Acting on halide bonds.      380.20
# 26                              Carbon-carbon lyases.    15310.45
# 27                              Carbon-oxygen lyases.    18009.45
# 28                            Carbon-nitrogen lyases.     3924.15
# 29                              Carbon-sulfur lyases.     1401.05
# 30                          Phosphorus-oxygen lyases.      855.15
# 31                          Racemases and epimerases.     5537.55
# 32                              Cis-trans-isomerases.     4067.45
# 33                    Intramolecular oxidoreductases.     6470.60
# 34                       Intramolecular transferases.    10468.75
# 35                             Intramolecular lyases.       99.90
# 36                       Forming carbon-oxygen bonds.    10157.90
# 37                       Forming carbon-sulfur bonds.     4215.70
# 38                     Forming carbon-nitrogen bonds.    21566.95
# 39                       Forming carbon-carbon bonds.     2887.25
# 40                    Forming phosphoric ester bonds.     1571.75
# 41                      Forming nitrogen-metal bonds.      586.40
#
#     sampleID_1a  sampleID_2  sampleID_2a
# 0       11285.0    29349.77     13763.62
# 1        8318.0    15864.96      9738.10
# 2        4535.6    13340.67      5260.47
# 3        3156.4     6335.26      3727.69
# 4        1463.2     5168.66      1811.29
# 5        5342.4    11451.50      6097.24
# 6        1197.6     5964.31      1287.19
# 7        2748.8     8102.01      3239.39
# 8         384.4     2967.20       444.80
# 9       17115.0    39333.75     19657.51
# 10       2803.8     5012.95      3131.50
# 11      10254.4    28748.64     12115.00
# 12       9894.6    15275.38     11061.05
# 13      10294.0    22532.26     11611.49
# 14       5159.4    11250.04      5930.17
# 15      37427.8    73007.36     42238.73
# 16       3881.4     9720.18      4405.92
# 17        162.0       59.00       183.00
# 18      11782.4    31951.55     13767.22
# 19       1044.4     5169.75      1350.70
# 20        456.8      843.11       520.18
# 21       6528.0    14883.50      7695.03
# 22       7600.8    22647.95      9504.60
# 23      12839.4    31578.19     14789.85
# 24        183.0     2066.71       301.58
# 25         19.4      630.20        12.80
# 26       9518.4    22480.23     11130.80
# 27      12357.4    26898.76     14179.77
# 28       2077.8     5458.80      2582.83
# 29        335.6     2178.60       405.61
# 30        770.8     1350.11       843.18
# 31       4339.6     8241.04      4830.75
# 32       1805.4     6092.34      2172.51
# 33       4234.2     9945.12      4796.36
# 34       6567.0    15930.91      7475.18
# 35        157.8       91.49       211.43
# 36       9279.8    15565.02     10361.36
# 37       1892.4     6597.13      2156.95
# 38      17590.4    32541.32     19974.59
# 39       1460.0     4361.31      1652.40
# 40       1030.0     2472.71      1206.58
# 41         55.8     1094.40        49.60

# %%
# Melt the DataFrame to long format
ec_long = ec_summarized.melt(
    id_vars=["class", "class_name", "subclass", "subclass_name"],
    var_name="sample",
    value_name="abundance"
)
ec_long
# Out:
#     class        class_name subclass  \
# 0       1  Oxidoreductases.      1.1
# 1       1  Oxidoreductases.      1.2
# 2       1  Oxidoreductases.      1.3
# 3       1  Oxidoreductases.      1.4
# 4       1  Oxidoreductases.      1.5
# ..    ...               ...      ...
# 163     6          Ligases.      6.2
# 164     6          Ligases.      6.3
# 165     6          Ligases.      6.4
# 166     6          Ligases.      6.5
# 167     6          Ligases.      6.6
#
#                                       subclass_name       sample  abundance
# 0              Acting on the CH-OH group of donors.   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors.   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors.   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors.   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors.   sampleID_1    3537.35
# ..                                              ...          ...        ...
# 163                    Forming carbon-sulfur bonds.  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds.  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds.  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds.  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds.  sampleID_2a      49.60
#
# [168 rows x 6 columns]

# %%
# Add condition/treatment metadata
ec_long_meta = ec_long.merge(meta[["ID","treatment1"]], how="left", left_on="sample", right_on="ID").drop("ID", axis=1)
for colname in ["class_name", "subclass_name"]:
    ec_long_meta[colname] = ec_long_meta[colname].str.replace(".","")
ec_long_meta
# Out:
#     class       class_name subclass  \
# 0       1  Oxidoreductases      1.1
# 1       1  Oxidoreductases      1.2
# 2       1  Oxidoreductases      1.3
# 3       1  Oxidoreductases      1.4
# 4       1  Oxidoreductases      1.5
# ..    ...              ...      ...
# 163     6          Ligases      6.2
# 164     6          Ligases      6.3
# 165     6          Ligases      6.4
# 166     6          Ligases      6.5
# 167     6          Ligases      6.6
#
#                                      subclass_name       sample  abundance  \
# 0              Acting on the CH-OH group of donors   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors   sampleID_1    3537.35
# ..                                             ...          ...        ...
# 163                    Forming carbon-sulfur bonds  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds  sampleID_2a      49.60
#
#     treatment1
# 0            b
# 1            b
# 2            b
# 3            b
# 4            b
# ..         ...
# 163          a
# 164          a
# 165          a
# 166          a
# 167          a
#
# [168 rows x 7 columns]

# %%
print("Number of classes:", ec_long_meta["class"].nunique())
print("Number of subclasses:", ec_long_meta["subclass"].nunique())
# Out:
# Number of classes: 6
# Number of subclasses: 42

# %%
# SETTING UP COLOURS FOR THE BOXPLOT CLASSES

# Get unique groups in the order they appear
group_labels = ec_long_meta["class_name"].unique().tolist()

# Keep only unique (class_name, subclass) pairs
unique_groups = ec_long_meta[["class_name", "subclass"]].drop_duplicates().reset_index()

# Compute bounds
group_bounds = (
    unique_groups.groupby("class_name")["index"]
    .apply(lambda x: (x.min(), x.max() + 1))
    .tolist()
)

group_colors = ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C', '#FB9A99', '#E31A1C']  # Soft pastel colors

print("Group Labels:", group_labels)
print("Group Bounds:", group_bounds)
print("Group Colours:", group_colors)
# Out:
# Group Labels: ['Oxidoreductases', 'Transferases', 'Hydrolases', 'Lyases', 'Isomerases', 'Ligases']
# Group Bounds: [(np.int64(18), np.int64(26)), (np.int64(31), np.int64(36)), (np.int64(36), np.int64(42)), (np.int64(26), np.int64(31)), (np.int64(0), np.int64(9)), (np.int64(9), np.int64(18))]
# Group Colours: ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C', '#FB9A99', '#E31A1C']

# %%
y_order = unique_groups["class_name"].unique() # not used, just in case

# %%
ec_long_meta
# Out:
#     class       class_name subclass  \
# 0       1  Oxidoreductases      1.1
# 1       1  Oxidoreductases      1.2
# 2       1  Oxidoreductases      1.3
# 3       1  Oxidoreductases      1.4
# 4       1  Oxidoreductases      1.5
# ..    ...              ...      ...
# 163     6          Ligases      6.2
# 164     6          Ligases      6.3
# 165     6          Ligases      6.4
# 166     6          Ligases      6.5
# 167     6          Ligases      6.6
#
#                                      subclass_name       sample  abundance  \
# 0              Acting on the CH-OH group of donors   sampleID_1   20981.25
# 1    Acting on the aldehyde or oxo group of donors   sampleID_1   10738.50
# 2              Acting on the CH-CH group of donors   sampleID_1    8920.80
# 3             Acting on the CH-NH2 group of donors   sampleID_1    4388.95
# 4              Acting on the CH-NH group of donors   sampleID_1    3537.35
# ..                                             ...          ...        ...
# 163                    Forming carbon-sulfur bonds  sampleID_2a    2156.95
# 164                  Forming carbon-nitrogen bonds  sampleID_2a   19974.59
# 165                    Forming carbon-carbon bonds  sampleID_2a    1652.40
# 166                 Forming phosphoric ester bonds  sampleID_2a    1206.58
# 167                   Forming nitrogen-metal bonds  sampleID_2a      49.60
#
#     treatment1
# 0            b
# 1            b
# 2            b
# 3            b
# 4            b
# ..         ...
# 163          a
# 164          a
# 165          a
# 166          a
# 167          a
#
# [168 rows x 7 columns]

# %%
# Create figure
fig,ax = plt.subplots(figsize=(14, 16))

# Remove whitespace in plot
category_positions = range(len(ec_long_meta['class'].unique()))
ax.set_ylim(min(category_positions), max(category_positions))

# Seaborn boxplot
sns.boxplot(x="abundance",
            y="subclass_name", 
            hue="treatment1", 
            data=ec_long_meta, 
            flierprops=dict(marker='o', markerfacecolor='black', markersize=0.75),
            ax=ax
           )

# Add background colors for each module (shade horizontal regions along y-axis)
for i, (group, (y_start, y_end), color) in enumerate(zip(group_labels, group_bounds, group_colors)):
    ax.axhspan(y_start - 0.5, y_end - 0.5, color=color, alpha=0.3, zorder=0)  # Background color
    ax.text(ax.get_xlim()[1], (y_start + y_end) / 2 - 0.5, group, 
            ha='left', va='center', fontsize=12, fontweight='bold')

# Title and labels
plt.title('Enzyme Commission Relative Abundances by Treatment', fontsize=16, fontweight='bold')
plt.xlabel('Abundance Value', fontweight='bold')
plt.ylabel('Enzyme Commission Sublass', fontweight='bold')
plt.legend(title='Condition', loc='lower right')

plt.show()
